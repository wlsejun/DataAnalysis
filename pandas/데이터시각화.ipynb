# %%
import pandas as pd

# %% [markdown]
# ## 샘플 데이터

# %% [markdown]
# [민간 아파트 동향 (clean)](https://bit.ly/ds-house-price-clean)

# %% [markdown]
# ## 데이터프레임 로드

# %%
df = pd.read_csv('https://bit.ly/ds-house-price-clean')

# %%
df
# Out:
#       지역             규모    연도   월   분양가
# 0     서울          60㎡이하  2015  10  5652
# 1     서울    60㎡초과 85㎡이하  2015  10  5882
# 2     서울   85㎡초과 102㎡이하  2015  10  5721
# 3     서울         102㎡초과  2015  10  5879
# 4     인천          60㎡이하  2015  10  3488
# ...   ..            ...   ...  ..   ...
# 3288  경남    60㎡초과 85㎡이하  2020   2  3065
# 3289  경남   85㎡초과 102㎡이하  2020   2  3247
# 3290  제주          60㎡이하  2020   2  4039
# 3291  제주    60㎡초과 85㎡이하  2020   2  3962
# 3292  제주         102㎡초과  2020   2  3601
#
# [3293 rows x 5 columns]

# %%
df.plot()
# Out:
# <Axes: >
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/events.py:93: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   func(*args, **kwargs)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/events.py:93: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   func(*args, **kwargs)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/events.py:93: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   func(*args, **kwargs)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/events.py:93: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   func(*args, **kwargs)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/events.py:93: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   func(*args, **kwargs)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/events.py:93: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   func(*args, **kwargs)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50900 (\N{HANGUL SYLLABLE WEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48516 (\N{HANGUL SYLLABLE BUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트가 깨지는 현상 해결 방법입니다.
#
# (참고 링크) [구글 코랩(colab) 한글 깨짐 현상 해결방법](https://teddylee777.github.io/colab/colab-korean/)

# %% [markdown]
# ### STEP 1. 아래 코드를 실행합니다.

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Password:
# sudo: a password is required
# Password:

# %%
# !brew tap homebrew/cask-fonts
# !brew install --cask font-nanum-gothic
# Out:
# ==> Cloning https://github.com/google/fonts.git
# Cloning into '/Users/worldlight/Library/Caches/Homebrew/Cask/font-nanum-gothic--git-sparse'...
# ==> Checking out branch main
# Already on 'main'
# Your branch is up to date with 'origin/main'.
# Warning: No checksum defined for cask 'font-nanum-gothic', skipping verification.
# ==> Installing Cask font-nanum-gothic
# ==> Moving Font 'NanumGothic-Bold.ttf' to '/Users/worldlight/Library/Fonts/Nanum
# ==> Moving Font 'NanumGothic-ExtraBold.ttf' to '/Users/worldlight/Library/Fonts/
# ==> Moving Font 'NanumGothic-Regular.ttf' to '/Users/worldlight/Library/Fonts/Na
# 🍺  font-nanum-gothic was successfully installed!

# %%
# !fc-cache -vf
# Out:
# zsh:1: command not found: fc-cache

# %% [markdown]
# ### STEP 2. 상단 메뉴 - 런타임 - 런타임 다시 시작을 클릭

# %% [markdown]
# ### STEP 3. 아래 코드를 한 번 더 실행 합니다.

# %%
import matplotlib.pyplot as plt
from matplotlib import rc  
rc('font', family='AppleGothic') 		

# Unicode warning 제거 (폰트 관련 경고메시지)
plt.rcParams['axes.unicode_minus']=False
# 한글 폰트 설정 (아래 나눔고딕 설정이 맥에서는 안됨)
# plt.rcParams['font.family'] = "NanumGothic"
# 그래프 출력 사이즈 설정
plt.rcParams["figure.figsize"] = (10, 6)

# %% [markdown]
# ### STEP 4. 필요한 패키지, 데이터 로딩

# %%
import pandas as pd

# %%
df = pd.read_csv('https://bit.ly/ds-house-price-clean')

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### STEP 5. Graph 사이즈 키우는 옵션

# %%
plt.rcParams["figure.figsize"] = (10, 7)

# %% [markdown]
# ## 1. Plot 그래프

# %% [markdown]
# plot은 일반 선그래프를 나타냅니다.

# %%
df = pd.read_csv('https://bit.ly/ds-house-price-clean')

# %% [markdown]
# kind 옵션을 통해 원하는 그래프를 그릴 수 있습니다.

# %% [markdown]
# kind 옵션:
# * line: 선그래프
# * bar: 바 그래프
# * barh: 수평 바 그래프
# * hist: 히스토그램
# * kde: 커널 밀도 그래프
# * hexbin: 고밀도 산점도 그래프
# * box: 박스 플롯
# * area: 면적 그래프
# * pie: 파이 그래프
# * scatter: 산점도 그래프

# %% [markdown]
# 데이터의 성격에 맞는 그래프 형식이 있습니다. 앞으로 차근차근 살펴보도록 하겠습니다.

# %% [markdown]
# ## line 그래프

# %% [markdown]
# * line 그래프는 데이터가 연속적인 경우 사용하기 적절합니다. (예를 들면, 주가 데이터)

# %%
df['분양가'].plot(kind='line')
# Out:
# <Axes: >

# %%
df_seoul = df.loc[df['지역'] == '서울']

# %%
df_seoul
# Out:
#       지역             규모    연도   월    분양가
# 0     서울          60㎡이하  2015  10   5652
# 1     서울    60㎡초과 85㎡이하  2015  10   5882
# 2     서울   85㎡초과 102㎡이하  2015  10   5721
# 3     서울         102㎡초과  2015  10   5879
# 64    서울          60㎡이하  2015  11   6320
# ...   ..            ...   ...  ..    ...
# 3178  서울         102㎡초과  2020   1   8779
# 3234  서울          60㎡이하  2020   2   8193
# 3235  서울    60㎡초과 85㎡이하  2020   2   8140
# 3236  서울   85㎡초과 102㎡이하  2020   2  13835
# 3237  서울         102㎡초과  2020   2   9039
#
# [212 rows x 5 columns]

# %%
df_seoul_year = df_seoul.groupby('연도').mean()
# Out:
# /var/folders/r1/6snszftx2gq_bcy3n5fw9hlc0000gn/T/ipykernel_7100/3064911928.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_seoul_year = df_seoul.groupby('연도').mean()

# %%
df_seoul_year.plot(kind='line')
# Out:
# <Axes: xlabel='연도'>

# %%
df_seoul_year['분양가'].plot(kind='line')
# Out:
# <Axes: xlabel='연도'>

# %% [markdown]
# ## bar 그래프

# %% [markdown]
# bar 그래프는 그룹별로 비교할 때 유용합니다.

# %%
df.groupby('지역')['분양가'].mean()
# Out:
# 지역
# 강원    2448.156863
# 경기    4133.952830
# 경남    2858.932367
# 경북    2570.465000
# 광주    3055.043750
# 대구    3679.620690
# 대전    3176.127389
# 부산    3691.981132
# 서울    7308.943396
# 세종    2983.543147
# 울산    2990.373913
# 인천    3684.302885
# 전남    2326.250000
# 전북    2381.416268
# 제주    3472.677966
# 충남    2534.950000
# 충북    2348.183962
# Name: 분양가, dtype: float64

# %%
df.groupby('지역')['분양가'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='지역'>

# %%
df.groupby('지역')['분양가'].mean().plot(kind='barh')
# Out:
# <Axes: ylabel='지역'>

# %% [markdown]
# ## 히스토그램 (hist)

# %% [markdown]
# 히스토그램은 **분포-빈도 를 시각화**하여 보여줍니다

# %% [markdown]
# 가로축에는 분포를, 세로축에는 빈도가 시각화되어 보여집니다.

# %%
df['분양가'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## 커널 밀도 그래프

# %% [markdown]
# * 히스토그램과 유사하게 밀도를 보여주는 그래프입니다.
# * 히스토그램과 유사한 모양새를 갖추고 있습니다.
# * 부드러운 라인을 가지고 있습니다.

# %%
# !pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.11.2-cp39-cp39-macosx_12_0_arm64.whl (29.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.6/29.6 MB 12.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/worldlight/anaconda3/envs/pandas/lib/python3.9/site-packages (from scipy) (1.24.3)
# Installing collected packages: scipy
# Successfully installed scipy-1.11.2

# %%
df['분양가'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Hexbin

# %% [markdown]
# * hexbin은 고밀도 산점도 그래프입니다.
# * x와 y 키 값을 넣어 주어야 합니다.
# * x, y 값 모두 numeric 한 값을 넣어 주어야합니다.
# * 데이터의 밀도를 추정합니다.

# %%
# 코드를 입력해 주세요
df.plot(kind='hexbin', x='분양가', y='연도', gridsize=20)
# Out:
# <Axes: xlabel='분양가', ylabel='연도'>

# %% [markdown]
# ## 박스 플롯(box)

# %%
df_seoul = df.loc[df['지역'] == '서울']

# %%
df_seoul['분양가'].plot(kind='box')
# Out:
# <Axes: >

# %%
from IPython.display import Image

# image source : https://justinsighting.com/how-to-interpret-box-plots/
Image('https://justinsighting.com/wp-content/uploads/2016/12/boxplot-description.png')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /Users/worldlight/Desktop/DataAnalysis/pandas/데이터시각화.ipynb Cell 55 line 4
#       <a href='vscode-notebook-cell:/Users/worldlight/Desktop/DataAnalysis/pandas/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> from IPython.display import Image
#       <a href='vscode-notebook-cell:/Users/worldlight/Desktop/DataAnalysis/pandas/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#Y102sZmlsZQ%3D%3D?line=2'>3</a> # image source : https://justinsighting.com/how-to-interpret-box-plots/
# ----> <a href='vscode-notebook-cell:/Users/worldlight/Desktop/DataAnalysis/pandas/%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94.ipynb#Y102sZmlsZQ%3D%3D?line=3'>4</a> Image('https://justinsighting.com/wp-content/uploads/2016/12/boxplot-description.png')
#
# File ~/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File ~/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File ~/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/display.py:1005, in Image.reload(self)
#    1003 """Reload the raw data from file or URL."""
#    1004 if self.embed:
# -> 1005     super(Image,self).reload()
#    1006     if self.retina:
#    1007         self._retina_shape()
#
# File ~/anaconda3/envs/pandas/lib/python3.9/site-packages/IPython/core/display.py:358, in DisplayObject.reload(self)
#     355 elif self.url is not None:
#     356     # Deferred import
#     357     from urllib.request import urlopen
# --> 358     response = urlopen(self.url)
#     359     data = response.read()
#     360     # extract encoding from header, if there is one:
#
# File ~/anaconda3/envs/pandas/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/anaconda3/envs/pandas/lib/python3.9/urllib/request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~/anaconda3/envs/pandas/lib/python3.9/urllib/request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~/anaconda3/envs/pandas/lib/python3.9/urllib/request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File ~/anaconda3/envs/pandas/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~/anaconda3/envs/pandas/lib/python3.9/urllib/request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 406: Not Acceptable

# %%
df_seoul.describe()
# Out:
#                연도           월           분양가
# count   212.00000  212.000000    212.000000
# mean   2017.45283    6.566038   7308.943396
# std       1.31439    3.603629   1402.869496
# min    2015.00000    1.000000   5061.000000
# 25%    2016.00000    3.000000   6519.750000
# 50%    2017.00000    7.000000   6895.500000
# 75%    2019.00000   10.000000   7732.000000
# max    2020.00000   12.000000  13835.000000

# %% [markdown]
# IQR은 Inter Quantile Range의 약어로써, (3Q - 1Q) * 1.5 값입니다.

# %%
IQR = (7732 - 6519.75) * 1.5
IQR
# Out:
# 1818.375

# %%
## 박스 플롯 max
7732 + IQR
# Out:
# 9550.375

# %%
## 박스 플롯 min
6519.75 - IQR
# Out:
# 4701.375

# %% [markdown]
# 박스플롯은 데이터 outlier 감지 할 떄 가장 많이 활용 되며, 25%, median, 75% 분위의 값을 활용하는 용도로 많이 활용됩니다.

# %% [markdown]
# ## area plot

# %% [markdown]
# * area plot은 line 그래프에서 아래 area를 모두 색칠해 주는 것이 특징입니다.

# %%
# 코드를 입력해 주세요
df.groupby('월')['분양가'].count().plot(kind='line')
# Out:
# <Axes: xlabel='월'>

# %%
df.groupby('월')['분양가'].count().plot(kind='area')
# Out:
# <Axes: xlabel='월'>

# %% [markdown]
# ## pie plot (파이 그래프)

# %% [markdown]
# pie는 대표적으로 데이터의 점유율을 보여줄 때 유용합니다.

# %%
# 코드를 입력해 주세요
df.groupby('연도')['분양가'].count().plot(kind='pie')
# Out:
# <Axes: ylabel='분양가'>

# %% [markdown]
# ## scatter plot (산점도 그래프)

# %% [markdown]
# * 점으로 데이터를 표기해 줍니다
# * x, y 값을 넣어주어야합니다 (hexbin과 유사)
# * x축과 y축을 지정해주면 그에 맞는 데이터 분포도를 볼 수 있습니다.
# * 역시 numeric 한 column 만 지정할 수 있습니다

# %%
# 코드를 입력해 주세요
df.plot(x='월', y='분양가', kind='scatter')
# Out:
# <Axes: xlabel='월', ylabel='분양가'>
